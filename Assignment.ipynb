# %% [markdown]
# ## Exploratory Fractal Analysis(EDA)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import nolds as nd

# %%
#Reading File
data = pd.read_csv("C:/Users/dharv/Downloads/intern_dataset.csv")

# %%
data.head()
# Out:
#                       Time       Signal1   Signal2 Label
# 0  2017-08-14 11:37:49.791  33668.091913  0.856726     A
# 1  2017-08-14 11:37:49.801  32564.903040  0.856705     A
# 2  2017-08-14 11:37:49.811  31454.043305  0.856683     A
# 3  2017-08-14 11:37:49.821  30335.387166  0.856659     A
# 4  2017-08-14 11:37:49.831  29207.142938  0.856634     A

# %%
data.tail()
# Out:
#                            Time       Signal1   Signal2 Label
# 911995  2020-01-04 10:55:49.186  34673.811155  0.151395     C
# 911996  2020-01-04 10:55:49.196  34672.951723  0.151385     C
# 911997  2020-01-04 10:55:49.206  34671.967555  0.151373     C
# 911998  2020-01-04 10:55:49.216  34670.877944  0.151359     C
# 911999  2020-01-04 10:55:49.226  34669.694865  0.151342     C

# %%
data.shape
# Out:
# (912000, 4)

# %%
#Describeing File
data.describe()
# Out:
#              Signal1        Signal2
# count  912000.000000  912000.000000
# mean    31315.380483       0.398004
# std     11700.734813       0.258119
# min     -2934.328327       0.113841
# 25%     23851.958837       0.162522
# 50%     30650.812455       0.261210
# 75%     37933.966586       0.546605
# max     67692.652022       1.356019

# %%
data.columns
# Out:
# Index(['Time', 'Signal1', 'Signal2', 'Label'], dtype='object')

# %%
data.nunique()
# Out:
# Time       912000
# Signal1    912000
# Signal2    912000
# Label           3
# dtype: int64

# %%
data['Label'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
#Checking for null value
data.isnull()
# Out:
#          Time  Signal1  Signal2  Label
# 0       False    False    False  False
# 1       False    False    False  False
# 2       False    False    False  False
# 3       False    False    False  False
# 4       False    False    False  False
# ...       ...      ...      ...    ...
# 911995  False    False    False  False
# 911996  False    False    False  False
# 911997  False    False    False  False
# 911998  False    False    False  False
# 911999  False    False    False  False
#
# [912000 rows x 4 columns]

# %%
#Checking for null value
data.isnull().sum()
# Out:
# Time       0
# Signal1    0
# Signal2    0
# Label      0
# dtype: int64

# %%
#droping Time to compare signal1 and signal2
student = data.drop(['Time'],axis=1)

# %%
student.head()
# Out:
#         Signal1   Signal2 Label
# 0  33668.091913  0.856726     A
# 1  32564.903040  0.856705     A
# 2  31454.043305  0.856683     A
# 3  30335.387166  0.856659     A
# 4  29207.142938  0.856634     A

# %%
corelation = student.corr()

# %%
#heatmap
sns.heatmap(corelation, xticklabels = corelation.columns, yticklabels = corelation.columns, annot = True)
# Out:
# <AxesSubplot:>

# %%
#Ploting pairwise relationships of two signal
sns.pairplot(student)

# %%
#relational plot
sns.relplot(x = 'Signal1', y = 'Signal2', hue='Label', data=student)

# %%
#distribution of observations
sns.distplot(student['Signal1'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Signal1', ylabel='Density'>

# %%
#distribution of observations
sns.distplot(student['Signal2'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Signal2', ylabel='Density'>

# %%
# drawing categorical plots
sns.catplot(x='Signal1', kind= 'box', data=student)

# %%
# drawing categorical plots
sns.catplot(x='Signal2', kind= 'box', data=student)

# %%
#data abot Label a
a = student[student.Label=='A']
a
# Out:
#              Signal1   Signal2 Label
# 0       33668.091913  0.856726     A
# 1       32564.903040  0.856705     A
# 2       31454.043305  0.856683     A
# 3       30335.387166  0.856659     A
# 4       29207.142938  0.856634     A
# ...              ...       ...   ...
# 317995  65807.274554  0.245727     A
# 317996  65692.473335  0.245748     A
# 317997  65472.863928  0.245770     A
# 317998  65147.555563  0.245792     A
# 317999  64715.020885  0.245815     A
#
# [318000 rows x 3 columns]

# %%
#data abot Label b
b = student[student.Label=='B']
b
# Out:
#              Signal1   Signal2 Label
# 510000  47842.554832  0.499167     B
# 510001  48258.447534  0.499155     B
# 510002  48654.923757  0.499143     B
# 510003  49015.036918  0.499130     B
# 510004  49323.169365  0.499117     B
# ...              ...       ...   ...
# 821995  30046.252223  0.546830     B
# 821996  32747.288036  0.546804     B
# 821997  35648.107903  0.546778     B
# 821998  38646.426455  0.546754     B
# 821999  41636.075714  0.546730     B
#
# [312000 rows x 3 columns]

# %%
#data abot Label c
c = student[student.Label=='C']
c
# Out:
#              Signal1   Signal2 Label
# 318000  22719.403196  0.123263     C
# 318001  23608.265317  0.123268     C
# 318002  24524.544926  0.123273     C
# 318003  25479.836092  0.123279     C
# 318004  26475.848059  0.123285     C
# ...              ...       ...   ...
# 911995  34673.811155  0.151395     C
# 911996  34672.951723  0.151385     C
# 911997  34671.967555  0.151373     C
# 911998  34670.877944  0.151359     C
# 911999  34669.694865  0.151342     C
#
# [282000 rows x 3 columns]

# %%
#Ploting pairwise relationships of two signal
sns.pairplot(a)

# %%
#Ploting pairwise relationships of two signal
sns.pairplot(b)

# %%
#Ploting pairwise relationships of two signal
sns.pairplot(c)

# %%
#Describeing Label a
a.describe()
# Out:
#              Signal1        Signal2
# count  318000.000000  318000.000000
# mean    30900.207581       0.371612
# std     14506.810996       0.157220
# min     -2934.328327       0.233280
# 25%     21734.338074       0.246235
# 50%     29487.372205       0.253411
# 75%     39622.622509       0.491799
# max     67692.652022       0.869459

# %%
#Describeing Label b
b.describe()
# Out:
#              Signal1        Signal2
# count  312000.000000  312000.000000
# mean    31693.976570       0.642296
# std     10693.240850       0.238301
# min     -1110.867137       0.318764
# 25%     23601.692942       0.410278
# 50%     30673.198029       0.635220
# 75%     39587.013733       0.801793
# max     67099.772581       1.356019

# %%
#Describeing Label c
c.describe()
# Out:
#              Signal1        Signal2
# count  282000.000000  282000.000000
# mean    31364.681913       0.157482
# std      8864.887863       0.010161
# min      4111.708945       0.113841
# 25%     26554.522791       0.153013
# 50%     31115.234365       0.160206
# 75%     34585.075333       0.162071
# max     65678.562412       0.223524

# %%
#Every thing below this is done by me first time so it may have some logical error it means, 
#it may have completed with wrong variable
#Detrended fluctuation analysis
nd.dfa(a['Signal1'])
# Out:
# 0.4681175097953122

# %%
#Detrended fluctuation analysis
nd.dfa(b['Signal1'])
# Out:
# 0.5966505334714576

# %%
#Detrended fluctuation analysis
nd.dfa(c['Signal1'])
# Out:
# 0.746298191724424

# %%
#Hurst exponent
nd.hurst_rs(a['Signal1'])
# Out:
# 0.5747595732623282

# %%
#Hurst exponent
nd.hurst_rs(a['Signal2'])
# Out:
# 0.9436455006528913

# %%
#Hurst exponent
nd.hurst_rs(b['Signal1'])
# Out:
# 0.6082193903732963

# %%
#Hurst exponent
nd.hurst_rs(b['Signal2'])
# Out:
# 0.9656017582527002

# %%
#Hurst exponent
nd.hurst_rs(c['Signal1'])
# Out:
# 0.7883751256345107

# %%
#Hurst exponent
nd.hurst_rs(c['Signal2'])
# Out:
# 0.8748319171563598
